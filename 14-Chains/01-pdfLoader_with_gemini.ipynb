# %%
from google import genai
from google.genai import types
import pathlib
import httpx

client = genai.Client()

# Retrieve and encode the PDF byte
file_path = pathlib.Path("data/deoksugung_pamphlet.pdf")


# Upload the PDF using the File API
sample_file = client.files.upload(
    file=file_path,
)

prompt = """pdf파일에서 텍스트 내용을 추출해줘. pdf는 페이지가 가로로 4페이지가 나란히 배치되어 있어.
            왼쪽페이지부터 차례로 읽어주고 불필요한 정보는 삭제해줘.
        """

response = client.models.generate_content(
    model="gemini-2.5-pro", contents=[sample_file, prompt]
)
print(response.text)
# Out:
# 다음은 PDF 파일의 텍스트 내용입니다. 왼쪽 페이지부터 순서대로 정리했습니다.
#
# ### **[1페이지: 관람 정보]**
#
# **관람 정보**
#
# **궁능유적본부 덕수궁관리소 SNS**
# @deoksugung_korea
#
# **관람시간**
# *   **덕수궁**: 09:00-21:00 (입장마감 20:00), 석조전 내부는 예약관람
# *   **돈덕전**: 09:00-17:30 (입장마감 17:00)
# *   **중명전**: 09:30-17:30 (입장마감 17:00)
# *   **고종의 길**: 09:00-17:30 (입장마감 17:20)
# *   **정기휴일**: 매주 월요일
#
# **관람요금**
# *   **개인 (만 25세-만 64세)**: 1,000원 / **단체(10인 이상)**: 800원
# *   만 24세 이하 및 만 65세 이상 내국인 무료
# *   지역(중구) 주민 50% 할인
# *   중명전은 무료
#
# **관람해설**
# *   자세한 언어권별 무료 안내해설 시간은 궁능유적본부 누리집(royal.khs.go.kr) 관람안내를 참고하시기 바랍니다.
# *   상황에 따라 관람과 해설 안내 시간이 변경 또는 취소될 수 있습니다.
#
# **덕수궁 해설**
# *   덕수궁 전각해설은 정문에서 20m 직진한 곳에 있는 종합안내판 앞에서 시작
# *   개인관람객(10인 미만)은 별도 예약없이 해설 참여 가능
# *   단체관람객(10인 이상)의 해설 참여는 사전예약 필수
# *   외국어 전각해설은 외국인만 참여 가능 (단, 외국인을 동반한 내국인에 한하여 참여 가능)
# *   공휴일은 외국어 해설 없음
#
# **석조전 대한제국역사관**
# *   궁능유적본부 누리집에서 예약 후 해설사와 동반하여 제한 관람 (선착순, 1인당 최대 5매까지 예약 가능)
# *   영어 관람해설은 외국인에 한하여 현장예약 문의 (단, 외국인을 동반한 내국인에 한하여 참여 가능)
#
# **오시는 길**
# *   시청역 1호선 2번 출구, 2호선 12번 출구 (*덕수궁에는 주차장이 없습니다.)
# *   04519 서울특별시 중구 세종대로 99 / 02-771-9951
#
# ---
#
# ### **[2페이지: 표지]**
#
# **덕수궁 / 석조전 / 돈덕전 / 중명전**
#
# **대한제국의 황궁**
#
# (표지 사진: 석조전)
#
# ---
#
# ### **[3페이지: 덕수궁 안내 및 지도]**
#
# 덕수궁은 조선 제14대 왕 선조가 임진왜란 때 피난을 갔다가 돌아온 후 월산대군의 후손들이 살던 집을 임시 거처[정릉동 행궁]로 삼으면서 처음 궁궐로 사용되었다. 이후 광해군이 창덕궁으로 옮겨 가면서 정릉동 행궁에 '경운궁(慶運宮)'이라는 이름을 붙였다. 경운궁에 다시 왕이 머문 것은 조선 제26대 왕 고종이 러시아공사관에 잠시 머물다가 경운궁으로 옮겨 오면서부터이다.
#
# 고종은 경운궁으로 돌아와 국호를 조선에서 대한제국으로 바꾸고, 환구단을 지어 하늘에 제사를 지낸 뒤 황제의 자리에 올랐다. 고종은 황제국의 위상에 걸맞게 여러 전각을 세우고 영역을 확장하였다. 당시 궁궐 영역은 현재의 약 세 배 규모였다. 1907년 일본의 강압에 의하여 고종이 황제의 자리에서 물러나면서부터 경운궁은 덕수궁(德壽宮)으로 불리었다. 고종은 1919년 승하할 때까지 덕수궁에서 지냈으며, 고종 승하 이후 덕수궁 권역이 빠르게 해체 및 축소되었다.
#
# **지도 범례**
# 1. 덕수궁 소개
# 2. 대한문
# 3. 중화문
# 4. 중화전
# 5. 준명당
# 6. 즉조당
# 7. 석어당
# 8. 덕홍전
# 9. 함녕전
# 10. 정관헌
# 11. 석조전 대한제국역사관
# 12. 국립현대미술관 덕수궁관
# 13. 광명문
# 14. 돈덕전
# 15. 고종의 길
# 16. 중명전
#
# **(편의시설)**
# *   해설 시작 장소
# *   매표소
# *   휠체어 대여소
# *   물품보관함
# *   화장실
# *   지하철
# *   기념품점
# *   카페
# *   구급약품
# *   수유실
# *   자동 심장 충격기
#
# ---
#
# ### **[4페이지: 상세 설명]**
#
# **대한제국 황궁 덕수궁**
#
# **덕수궁과 조선-대한제국의 역사**
# *   **1392** 조선 건국
# *   **1593** 월산대군 후손의 저택을 임시 궁궐로 삼고, '정릉동 행궁'이라 부름
# *   **1611** 광해군, 정릉동 행궁을 '경운궁'이라 칭함
# *   **1897** 고종, 경운궁으로 옮김. 대한제국 선포
# *   **1904** 대화재로 중화전, 석어당, 함녕전 등 전각 소실
# *   **1905** 중명전에서 을사늑약 강제 체결
# *   **1907** 순종 즉위 후, 경운궁을 '덕수궁'으로 부르기 시작
# *   **1910** 석조전 완공. 국권 피탈
# *   **1919** 함녕전에서 고종 승하
# *   **1920년대** 돈덕전 훼철
# *   **1938** 석조전 서관 완공. '이왕가미술관'으로 개관
# *   **1946~7** 석조전에서 미소공동위원회 열림
# *   **2010** 중명전 전시관 개관
# *   **2014** 석조전 대한제국역사관 개관
# *   **2023** 돈덕전 재건 및 개관
#
# **중화전 영역**
# 고종은 1897년 대한제국을 선포한 후 황제국의 위상에 맞게 덕수궁을 정비하였다. 정전인 중화전은 1902년 지었을 때 중층이었지만, 1904년 화재를 겪고 1905년 다시 지으면서 단층으로 축소되었다. 즉조당과 석어당은 선조가 임시로 거처했을 때부터 사용한 유서 깊은 건물이다. 석어당은 덕수궁에 남아 있는 유일한 중층 목조 전각이다.
#
# **함녕전 영역**
# 함녕전은 고종의 침전으로 사용되었고, 고종이 승하한 장소이기도 하다. 덕홍전은 외국 사신을 접견할 목적으로 사용되었으며 외관은 전통식이지만 내부는 서양식으로 꾸몄다. 정관헌은 고종과 순종의 어진(초상화) 등을 봉안한 건물이다.
#
# **석조전**
# 석조전은 1897년 대한제국 선포 후 건립을 계획하여 1910년에 준공하였다. 신고전주의 양식으로 내부에 접견실, 대식당, 침실 등을 갖춘 근대 건축물이다. 1층은 황실의 공적 공간, 2층은 사적 공간으로 재현하였다. 2014년에 1910년 준공 당시의 모습으로 복원하여 석조전 대한제국역사관으로 개관하였다.
#
# **돈덕전**
# 돈덕전은 대한제국의 서양식 외교 건물로, 1902~3년에 고종 즉위 40주년 기념 예식에 맞추어 대규모 국제행사장으로 지어졌다. 외교 사절의 접견실이자 연회장, 국빈급 외국인의 숙소 등으로 사용되었다. 1907년에는 순종의 황제 즉위식이 열리기도 하였다. 돈덕전은 1920년대 일제에 의해 훼철되었으나, 복원정비사업을 거쳐 2023년에 개관하였다.
#
# **중명전**
# 중명전은 대한제국 황궁으로 정비하는 과정에서 황실 서적과 보물을 보관할 황제의 서재로 지어졌다. 1904년 덕수궁 화재로 고종이 중명전으로 거처를 옮기면서 편전으로 사용되었다. 그러나 이듬해인 1905년 일본의 강압으로 을사늑약이 체결되는 비운의 장소가 되었다.
