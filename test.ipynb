# %%
from typing import List

def add_numbers(nums: List[int]) -> int:
    return (nums)

print(add_numbers([1, 2, 3]))   # ✅ 정상
print(add_numbers(["a", "b"]))  # ❌ 실행은 되지만 타입 힌트 무시됨
# Out:
# [1, 2, 3]
# ['a', 'b']
